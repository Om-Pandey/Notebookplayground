# %%
#

# %%
# !pip install unicodecsv --user
# Out:
# Requirement already satisfied: unicodecsv in ./.local/lib/python3.5/site-packages (0.14.1)

# %%
from lxml import html
import requests
import unicodecsv as csv
import argparse
import json
from urllib.request import Request, urlopen


def clean(text):
    if text:
        return ' '.join(' '.join(text).split())
    return None


def get_headers():
    # Creating headers.
    headers = {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
               'accept-encoding': 'gzip, deflate, sdch, br',
               'accept-language': 'en-GB,en;q=0.8,en-US;q=0.6,ml;q=0.4',
               'cache-control': 'max-age=0',
               'upgrade-insecure-requests': '1',
               'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
    return headers


def create_url(zipcode):
    # Creating Zillow URL based on the filter.
    url = "https://www.zillow.com/homes/for_sale/{0}_rb/?fromHomePage=true&shouldFireSellPageImplicitClaimGA=false&fromHomePageTab=buy".format(zipcode)
    print(url)
    return url

# %%
def save_to_file(response):
    # saving response to `response.html`

    with open("response.html", 'wb') as fp:
        fp.write((response.text).encode('utf8')) 


def write_data_to_csv(data):
    # saving scraped data to csv.

    with open("properties-%s.csv" % (zipcode), 'wb') as csvfile:
        fieldnames = ['title', 'address', 'city', 'state', 'postal_code', 'price', 'facts and features', 'real estate provider', 'url']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)


def get_response(url):
    # Getting response from zillow.com.

    for i in range(5):
        response = requests.get(url, headers=get_headers())
        print("status code received:", response.status_code)
        if response.status_code != 200:
            # saving response to file for debugging purpose.
            save_to_file(response)
            continue
        else:
            save_to_file(response)
            return response
    return None

def get_data_from_json(raw_json_data):
    # getting data from json (type 2 of their A/B testing page)

    cleaned_data = clean(raw_json_data).replace('<!--', "").replace("-->", "")
    properties_list = []

    try:
        json_data = json.loads(cleaned_data)
        search_results = json_data.get('searchResults').get('listResults', [])

        for properties in search_results:
            address = properties.get('addressWithZip')
            property_info = properties.get('hdpData', {}).get('homeInfo')
            city = property_info.get('city')
            state = property_info.get('state')
            postal_code = property_info.get('zipcode')
            price = properties.get('price')
            bedrooms = properties.get('beds')
            bathrooms = properties.get('baths')
            area = properties.get('area')
            info = r'{bedrooms} bds, {bathrooms} ba ,{area} sqft'
            broker = properties.get('brokerName')
            property_url = properties.get('detailUrl')
            title = properties.get('statusText')

            data = {'address': address,
                    'city': city,
                    'state': state,
                    'postal_code': postal_code,
                    'price': price,
                    'facts and features': info,
                    'real estate provider': broker,
                    'url': property_url,
                    'title': title}
            properties_list.append(data)

        return properties_list

    except ValueError:
        print("Invalid json")
        return None

# %%
def parse(zipcode, filter=None):
		url = create_url(zipcode)
		response = get_response(url)

		if not response:
			print("Failed to fetch the page, please check `response.html` to see the response received from zillow.com.")
			return None

		req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
		webpage = urlopen(req).read()

		parser = html.fromstring(webpage)

		search_results = parser.xpath("//div[@id='search-results']//article")

		if not search_results:
			print("parsing from json data")
		# identified as type 2 page
			raw_json_data = parser.xpath('//script[@data-zrr-shared-data-key="mobileSearchPageStore"]//text()')
			return get_data_from_json(raw_json_data)

		print("parsing from html page")
		properties_list = []
		for properties in search_results:
			raw_address = properties.xpath(".//span[@itemprop='address']//span[@itemprop='streetAddress']//text()")
			raw_city = properties.xpath(".//span[@itemprop='address']//span[@itemprop='addressLocality']//text()")
			raw_state = properties.xpath(".//span[@itemprop='address']//span[@itemprop='addressRegion']//text()")
			raw_postal_code = properties.xpath(".//span[@itemprop='address']//span[@itemprop='postalCode']//text()")
			raw_price = properties.xpath(".//span[@class='zsg-photo-card-price']//text()")
			raw_info = properties.xpath(".//span[@class='zsg-photo-card-info']//text()")
			raw_broker_name = properties.xpath(".//span[@class='zsg-photo-card-broker-name']//text()")
			url = properties.xpath(".//a[contains(@class,'overlay-link')]/@href")
			raw_title = properties.xpath(".//h4//text()")

			address = clean(raw_address)
			city = clean(raw_city)
			state = clean(raw_state)
			postal_code = clean(raw_postal_code)
			price = clean(raw_price)
			info = clean(raw_info).replace(u"\xb7", ',')
			broker = clean(raw_broker_name)
			title = clean(raw_title)
			property_url = "https://www.zillow.com" + url[0] if url else None
			is_forsale = properties.xpath('.//span[@class="zsg-icon-for-sale"]')

			properties = {'address': address,
						  'city': city,
						  'state': state,
						  'postal_code': postal_code,
						  'price': price,
						  'facts and features': info,
						  'real estate provider': broker,
						  'url': property_url,
						  'title': title}
			if is_forsale:
				properties_list.append(properties)
		return properties_list

# %%
if __name__ == "__main__":
    # Reading arguments
    zipcode = 77048 #please include the zipcode here
    print ("Fetching data for %s" % (zipcode))
    scraped_data = parse(zipcode)
    if scraped_data:
        print ("Writing data to output file")
        write_data_to_csv(scraped_data)
# Out:
# Fetching data for 77048
# https://www.zillow.com/homes/for_sale/77048_rb/?fromHomePage=true&shouldFireSellPageImplicitClaimGA=false&fromHomePageTab=buy
# status code received: 200
# parsing from json data
# Writing data to output file

# %%
import numpy as np
final_list= [[*scraped_data[0].keys()]]
for i in range(len(scraped_data)):
    final_list.append([*scraped_data[i].values()])

# %%
#final_list[0]

# %%
import pandas as pd
df = pd.DataFrame(final_list)
df
# Out:
#                                               0          1  \
# 0                          real estate provider      price
# 1                                          None   $200,900
# 2                 Keller Williams Hou Preferred   $145,000
# 3                                   Coton House   $135,000
# 4                               RE/MAX Pearland   $208,000
# 5                                      Opendoor   $178,000
# 6                               Alpha, REALTORS   $239,990
# 7                             Correa Properties   $145,000
# 8                     Angel Pro Real Estate LLC   $155,000
# 9                 Keller Williams Professionals   $214,490
# 10                Keller Williams Professionals   $214,240
# 11                          Apex Brokerage, LLC   $156,880
# 12                Keller Williams Hou Preferred   $179,500
# 13                             The Horizon Team   $159,000
# 14                      Lifestyles Realty, Inc.   $157,000
# 15                                  Ashoka Lion   $168,000
# 16                      Offerpad Brokerage, LLC   $209,900
# 17                         Tom Parks Properties    $96,000
# 18                      Lifestyles Realty, Inc.   $163,000
# 19                              RE/MAX PIONEERS   $229,900
# 20                                    LGI Homes  $177,900+
# 21                Keller Williams Professionals   $207,210
# 22                            Walzel Properties   $244,900
# 23                                    LGI Homes  $192,900+
# 24                                  Auction.com
# 25  Coldwell Banker Realty - Pearland/Galveston   $234,900
# 26                   Keller Williams Realty -SW   $146,525
# 27                       Door Texas Realty, LLC   $145,000
# 28                                    LGI Homes   $224,900
# 29                             Intercity Realty   $120,000
# 30                Keller Williams Professionals   $219,990
# 31                                    LGI Homes   $204,900
# 32                         Beth Wolff, REALTORS   $229,900
# 33                          Hamilton Properties   $110,000
# 34                                         None       None
# 35                               D. Real Estate   $139,500
# 36                             Home Team Realty   $100,000
# 37                             Lone Star Realty   $125,000
# 38                                    LGI Homes   $191,900
# 39                  Champions Real Estate Group   $139,900
# 40                                    LGI Homes   $177,900
#
#                                               2      3  \
# 0                            facts and features  state
# 1   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 2   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 3   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 4   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 5   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 6   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 7   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 8   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 9   {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 10  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 11  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 12  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 13  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 14  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 15  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 16  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 17  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 18  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 19  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 20  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 21  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 22  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 23  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 24  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 25  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 26  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 27  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 28  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 29  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 30  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 31  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 32  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 33  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 34  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 35  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 36  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 37  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 38  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 39  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
# 40  {bedrooms} bds, {bathrooms} ba ,{area} sqft     TX
#
#                                                     4            5        6  \
# 0                                                 url  postal_code     city
# 1   https://www.zillow.com/homedetails/6403-Dayrid...        77048  Houston
# 2   https://www.zillow.com/homedetails/12719-Green...        77048  Houston
# 3   https://www.zillow.com/homedetails/5310-Grace-...        77048  Houston
# 4   https://www.zillow.com/homedetails/14003-Dayri...        77048  Houston
# 5   https://www.zillow.com/homedetails/5619-Abunda...        77048  Houston
# 6   https://www.zillow.com/homedetails/6607-Caprid...        77048  Houston
# 7   https://www.zillow.com/homedetails/12127-Rockf...        77048  Houston
# 8   https://www.zillow.com/homedetails/5615-Greylo...        77048  Houston
# 9   https://www.zillow.com/homedetails/6420-Innsbr...        77048  Houston
# 10  https://www.zillow.com/homedetails/6420-Macroo...        77048  Houston
# 11  https://www.zillow.com/homedetails/4910-Richfi...        77048  Houston
# 12  https://www.zillow.com/homedetails/10602-Roand...        77048  Houston
# 13  https://www.zillow.com/homedetails/5511-Elm-Tr...        77048  Houston
# 14  https://www.zillow.com/homedetails/5443-Osprey...        77048  Houston
# 15  https://www.zillow.com/homedetails/6150-El-Gra...        77048  Houston
# 16  https://www.zillow.com/homedetails/14023-Autum...        77048  Houston
# 17  https://www.zillow.com/homedetails/4906-Paradi...        77048  Houston
# 18  https://www.zillow.com/homedetails/5427-Osprey...        77048  Houston
# 19  https://www.zillow.com/homedetails/6406-Dayrid...        77048  Houston
# 20  https://www.zillow.com/community/el-tesoro/208...        77048  Houston
# 21  https://www.zillow.com/homedetails/6410-Innsbr...        77048  Houston
# 22  https://www.zillow.com/homedetails/4107-Waysid...        77048  Houston
# 23  https://www.zillow.com/community/el-tesoro/208...        77048  Houston
# 24  https://www.zillow.com/homedetails/5111-Madden...        77048  Houston
# 25  https://www.zillow.com/homedetails/6803-Corten...        77048  Houston
# 26  https://www.zillow.com/homedetails/11411-Jutla...        77048  Houston
# 27  https://www.zillow.com/homedetails/12710-Sandr...        77048  Houston
# 28  https://www.zillow.com/homedetails/11606-El-Ru...        77048  Houston
# 29  https://www.zillow.com/homedetails/6315-Airpor...        77048  Houston
# 30  https://www.zillow.com/homedetails/6425-Macroo...        77048  Houston
# 31  https://www.zillow.com/homedetails/6219-El-Top...        77048  Houston
# 32  https://www.zillow.com/homedetails/6650-Atlasr...        77048  Houston
# 33  https://www.zillow.com/homedetails/4902-Meadow...        77048  Houston
# 34  https://www.zillow.com/homedetails/12007-Panay...        77048  Houston
# 35  https://www.zillow.com/homedetails/4718-Meadow...        77048  Houston
# 36  https://www.zillow.com/homedetails/0-Almeda-Ge...        77048  Houston
# 37  https://www.zillow.com/homedetails/5530-Elm-Sp...        77048  Houston
# 38  https://www.zillow.com/homedetails/6230-El-Oro...        77048  Houston
# 39  https://www.zillow.com/homedetails/5026-Richfi...        77048  Houston
# 40  https://www.zillow.com/homedetails/6154-El-Oro...        77048  Houston
#
#           7                    8
# 0   address                title
# 1      None       House for sale
# 2      None       House for sale
# 3      None       House for sale
# 4      None       House for sale
# 5      None       House for sale
# 6      None       House for sale
# 7      None       House for sale
# 8      None       House for sale
# 9      None     New construction
# 10     None     New construction
# 11     None       House for sale
# 12     None       House for sale
# 13     None       House for sale
# 14     None       House for sale
# 15     None       House for sale
# 16     None       House for sale
# 17     None       House for sale
# 18     None       House for sale
# 19     None       House for sale
# 20     None     New construction
# 21     None     New construction
# 22     None       House for sale
# 23     None     New construction
# 24     None              Auction
# 25     None       House for sale
# 26     None       House for sale
# 27     None       House for sale
# 28     None     New construction
# 29     None       House for sale
# 30     None     New construction
# 31     None     New construction
# 32     None       House for sale
# 33     None       House for sale
# 34     None           Foreclosed
# 35     None       House for sale
# 36     None  Lot / Land for sale
# 37     None       House for sale
# 38     None     New construction
# 39     None       House for sale
# 40     None     New construction
